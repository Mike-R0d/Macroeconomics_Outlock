# %% [markdown]
# <a href="https://colab.research.google.com/github/Mike-R0d/Macroeconomics_Outlock_Canada/blob/main/CRUD_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stats_can

from stats_can import StatsCan
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# Obtener los datos del PIB de las provincias de Canadá
sc = StatsCan()
df = sc.table_to_df("36-10-0222-01")
df
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/stats_can/api_class.py:24: FutureWarning: This class will be deprecated in upcoming v3 release. Please see the docs for details
#   warn(
# /usr/local/lib/python3.10/dist-packages/stats_can/sc.py:608: FutureWarning: This function will be deprecated in the v3 release. Please see the docs for details.
#   warn(
# /usr/local/lib/python3.10/dist-packages/stats_can/sc.py:326: FutureWarning: This function will be deprecated in the v3 release. Please see the docs for details.
#   warn(
# ...
# /usr/local/lib/python3.10/dist-packages/stats_can/sc.py:276: FutureWarning: This function will be deprecated in the v3 release. Please see the docs for details.
#   warn(
# 36100222-eng.zip: 100%|██████████| 2.29M/2.29M [00:02<00:00, 836kB/s]
# /usr/local/lib/python3.10/dist-packages/stats_can/sc.py:224: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
# ...

# %% [markdown]
# Hellow

# %%
from google.colab import drive
drive.mount('/content/drive')

# export df to csv path =  /content/drive/MyDrive/pib_provincias_canada.csv

df.to_csv('/content/drive/MyDrive/20240916_Industrial_Analisis_Canada/pib_provincias.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Hi how are you
